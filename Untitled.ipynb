# %%
from requests_html import HTMLSession
import datetime
import pickle
import re


# home_addrs = ["https://wsjkw.sh.gov.cn/yqtb/index_3.html"]

def process_content_type1(c, dic):
    if "入关" in c:
        return
    
    if  c.startswith("无症状感染者"):
        content_type = "Asymptomatic"
        mark_content = "无症状感染者"
    elif c.startswith("病例"):
        content_type = "ConfirmedCases"
        mark_content = "病例"
    else:
        return 
    
    if "本市闭环隔离管控人员" in c:
        control_type = "In_control"
    elif "为此前报告的本土无症状感染者" in c:
        control_type = "FromAsymptomatic"
    else:
        control_type = "Out_control"
        
    if not content_type in dic:
        dic[content_type] = {}
    if not control_type in dic[content_type]:
        dic[content_type][control_type] = {}
        
    c = c.split("，")
    
    for i in range(len(c)>>1):
        if c[2*i].startswith(mark_content):
            patients = c[2*i].split('—')
            
            if len(patients) == 2:
                s = int(patients[0][len(mark_content):])
                if patients[1].startswith(mark_content):
                    e = int(patients[1][len(mark_content):])
                else:
                    e = int(patients[1])
                num = e-s+1
            elif "、" in c[2*i]:
                num = len(c[2*i].split("、" ))
            else:
                num = 1
        
            addr = c[2*i+1][3:]
            dic[content_type][control_type][addr] = num

        else:
            break    
    return

def process_content_type2(c, dic):
    if "入关" in c:
        return
    
    if  c.startswith("无症状感染者"):
        content_type = "Asymptomatic"
        mark_content = "无症状感染者"
    elif c.startswith("病例"):
        content_type = "ConfirmedCases"
        mark_content = "病例"
    else:
        return 
    
    if "本市闭环隔离管控人员" in c:
        control_type = "In_control"
    elif "为此前报告的本土无症状感染者" in c:
        control_type = "FromAsymptomatic"
    else:
        control_type = "Out_control"
        
    if not content_type in dic:
        dic[content_type] = {}
    if not control_type in dic[content_type]:
        dic[content_type][control_type] = {}
        
    c = c.split("，")
    
    for i in range(len(c)>>2):
        if c[4*i].startswith(mark_content):        
            addr = c[4*i+3][3:]
            if not addr in dic[content_type][control_type]:
                dic[content_type][control_type][addr] = 1
            else:
                dic[content_type][control_type][addr] += 1
        else:
            break    
    return

startdate = datetime.datetime.strptime('2022-3-19','%Y-%m-%d').date()
threshdate = datetime.datetime.strptime('2022-3-25','%Y-%m-%d').date()

session = HTMLSession()
home_addrs = ["http://wsjkw.sh.gov.cn/yqtb/", "https://wsjkw.sh.gov.cn/yqtb/index_2.html", "https://wsjkw.sh.gov.cn/yqtb/index_3.html"]

# with open("data/all.pkl",'rb') as df:
#     all_data = pickle.load(df)

all_data = {}
    
for ha in home_addrs:
    session = HTMLSession()
    r = session.get(ha)
    items = r.html.find('ul.uli16', first=True).find('li')
    news = []
    for item in items:
        cur = item.find('a', first=True)
        href = cur.attrs['href']
        title = cur.attrs['title']
        
#         print (href, title)
        
        if href.startswith("https") or not title.startswith("上海"):
            continue
        absolute_href = "https://wsjkw.sh.gov.cn"+href
        
        
        
        date = title.split("，")[0][2:-1]
       
        date = date.replace("年","-").replace("月","-")
        dt = datetime.datetime.strptime(date,'%Y-%m-%d').date()
        
        if str(dt) in all_data or dt <= startdate:
            break
        
        print (absolute_href,title)
        s = session.get(absolute_href)
        content =  s.html.xpath('//*[@id="ivs_content"]', first=True).text
        dic = {}
        for c in content.split():
            if dt > threshdate:
                process_content_type1(c, dic)
            else:
                process_content_type2(c, dic)
        
            all_confirmed_cases = re.search(r'累计本土确诊(\d+)例', c)
            if all_confirmed_cases:
                dic['all_confirmed_cases'] = all_confirmed_cases.group(1)
            else:
                continue

            all_cured_cases = re.search(r'治愈出院(\d+)例', c)
            if all_cured_cases:
                dic['all_cured_cases'] = all_cured_cases.group(1)

            all_in_treatment= re.search(r'在院治疗(\d+)例', c)
            if all_in_treatment:
                dic['all_in_treatment'] = all_in_treatment.group(1)

            all_critical_cases = re.search(r'其中重症(\d+)例', c)
            if all_critical_cases:
                dic['all_critical_cases'] = all_critical_cases.group(1)

            all_in_observation = re.search(r'现有待排查的疑似病例(\d+)例', c)
            if all_in_observation:
                dic['all_in_observation'] = all_in_observation.group(1)

            all_deaths =  re.search(r'死亡(\d+)例', c)
            if all_deaths:
                dic['all_deaths'] = all_deaths.group(1)
        
#         print(all_confirmed_cases,all_cured_cases,all_in_treatment,all_critical_cases,all_in_observation)
        
        all_data[str(dt)] = dic
        
#         break
#     break
        
# with open("data/all.pkl",'wb') as df:
#     pickle.dump(all_data, df)

# print(all_data)
# Out:
# https://wsjkw.sh.gov.cn/xwfb/20220418/5d14378ff19443cd82887f378e35066a.html 上海2022年4月17日，新增本土新冠肺炎确诊病例2417例 新增本土无症状感染者19831例 新增境外输入性新冠肺炎确诊病例3例 无新增境外输入性无症状感染者
# https://wsjkw.sh.gov.cn/xwfb/20220417/00308b74d3b74d9894cf8e7746ac6d3b.html 上海2022年4月16日，新增本土新冠肺炎确诊病例3238例 新增本土无症状感染者21582例 新增境外输入性新冠肺炎确诊病例2例 无新增境外输入性无症状感染者
# https://wsjkw.sh.gov.cn/xwfb/20220416/dfbb15a0fe3b401dbead8b10995b3431.html 上海2022年4月15日，新增本土新冠肺炎确诊病例3590例 新增本土无症状感染者19923例 新增境外输入性新冠肺炎确诊病例4例 新增境外输入性无症状感染者2例
# https://wsjkw.sh.gov.cn/xwfb/20220415/c68d08a1d5ac4ae3b8612559d19d489c.html 上海2022年4月14日，新增本土新冠肺炎确诊病例3200例 新增本土无症状感染者19872例 无新增境外输入性新冠肺炎确诊病例 新增境外输入性无症状感染者1例 治愈出院549例  解除医学观察8071例
# https://wsjkw.sh.gov.cn/xwfb/20220414/083cc562d92d4641b8acf1eccaf38420.html 上海2022年4月13日，新增本土新冠肺炎确诊病例2573例 新增本土无症状感染者25146例 无新增境外输入性新冠肺炎确诊病例 新增境外输入性无症状感染者1例 治愈出院741例  解除医学观察15406例
# https://wsjkw.sh.gov.cn/xwfb/20220413/56947d2bb86d433e8a6520825eeb66c0.html 上海2022年4月12日，新增本土新冠肺炎确诊病例1189例 新增本土无症状感染者25141例 新增境外输入性新冠肺炎确诊病例1例 无新增境外输入性无症状感染者 治愈出院341例
# https://wsjkw.sh.gov.cn/xwfb/20220412/eaf942f663204853826ee6fc29abbeb8.html 上海2022年4月11日，新增本土新冠肺炎确诊病例994例 新增本土无症状感染者22348例 新增境外输入性新冠肺炎确诊病例4例 新增境外输入性无症状感染者1例 治愈出院391例
# https://wsjkw.sh.gov.cn/xwfb/20220411/f6021ae6ceb04596b4b8cde4c1e5511a.html 上海2022年4月10日，新增本土新冠肺炎确诊病例914例 新增本土无症状感染者25173例 新增境外输入性新冠肺炎确诊病例3例 治愈出院298例
# https://wsjkw.sh.gov.cn/xwfb/20220410/95b812b6e8a649b49aca8382051957bf.html 上海2022年4月9日，新增本土新冠肺炎确诊病例1006例 新增本土无症状感染者23937例 新增境外输入性新冠肺炎确诊病例9例 新增境外输入性无症状感染者2例 治愈出院227例
# https://wsjkw.sh.gov.cn/xwfb/20220409/52eee46f25a64af1a5f4e1ddb72c4324.html 上海2022年4月8日，新增本土新冠肺炎确诊病例1015例 新增本土无症状感染者22609例 新增境外输入性新冠肺炎确诊病例2例 新增境外输入性无症状感染者2例 治愈出院119例
# https://wsjkw.sh.gov.cn/xwfb/20220408/779c3f24bc7e4f1fb3fef52dbfb51156.html 上海2022年4月7日，新增本土新冠肺炎确诊病例824例 新增本土无症状感染者20398例 新增境外输入性新冠肺炎确诊病例4例 新增境外输入性无症状感染者3例 治愈出院57例
# https://wsjkw.sh.gov.cn/xwfb/20220407/ca59cfd635a045c3b3cc4bd496b6eae2.html 上海2022年4月6日，新增本土新冠肺炎确诊病例322例 新增本土无症状感染者19660例 新增境外输入性新冠肺炎确诊病例7例 新增境外输入性无症状感染者1例 治愈出院47例
# https://wsjkw.sh.gov.cn/xwfb/20220406/9873e70ae1d14cdcb2c9b6e8c9f8a8ba.html 上海2022年4月5日，新增本土新冠肺炎确诊病例311例 新增本土无症状感染者16766例 新增境外输入性新冠肺炎确诊病例4例 新增境外输入性无症状感染者1例 治愈出院41例
# https://wsjkw.sh.gov.cn/xwfb/20220405/c80df81fd8904247a218904b8b4a124f.html 上海2022年4月4日，新增本土新冠肺炎确诊病例268例 新增本土无症状感染者13086例 新增境外输入性新冠肺炎确诊病例3例 新增境外输入性无症状感染者2例 治愈出院27例
# https://wsjkw.sh.gov.cn/xwfb/20220404/b8e4ccf803f0481e84a84507accdb565.html 上海2022年4月3日，新增本土新冠肺炎确诊病例425例 新增本土无症状感染者8581例 新增境外输入性新冠肺炎确诊病例8例 新增境外输入性无症状感染者4例 治愈出院30例
# https://wsjkw.sh.gov.cn/xwfb/20220403/58bcd8f1e6ad45c1b190ee81e3c02942.html 上海2022年4月2日，新增本土新冠肺炎确诊病例438例 新增本土无症状感染者7788例 新增境外输入性新冠肺炎确诊病例6例 新增境外输入性无症状感染者1例 治愈出院31例
# https://wsjkw.sh.gov.cn/xwfb/20220402/7e9cc0574a4d4ef482c21286762c56fa.html 上海2022年4月1日，新增本土新冠肺炎确诊病例260例 新增本土无症状感染者6051例 新增境外输入性新冠肺炎确诊病例2例 无新增境外输入性无症状感染者 治愈出院39例
# https://wsjkw.sh.gov.cn/xwfb/20220401/f08047a77e7347edafed1bdbb46e2547.html 上海2022年3月31日，新增本土新冠肺炎确诊病例358例 新增本土无症状感染者4144例 新增境外输入性新冠肺炎确诊病例7例 新增境外输入性无症状感染者1例 治愈出院26例
# https://wsjkw.sh.gov.cn/xwfb/20220331/81df7d8493ad493c8ca301bcfaa348ea.html 上海2022年3月30日，新增本土新冠肺炎确诊病例355例 新增本土无症状感染者5298例 新增境外输入性新冠肺炎确诊病例3例 新增境外输入性无症状感染者1例 治愈出院29例
# https://wsjkw.sh.gov.cn/xwfb/20220330/875ac4e3116341c1ab706b7b77a7ef31.html 上海2022年3月29日，新增本土新冠肺炎确诊病例326例 新增本土无症状感染者5656例 新增境外输入性新冠肺炎确诊病例3例 新增境外输入性无症状感染者2例 治愈出院45例
# https://wsjkw.sh.gov.cn/xwfb/20220329/147ddbec518c4d26b5b4a4492dbf0650.html 上海2022年3月28日，新增本土新冠肺炎确诊病例96例 新增本土无症状感染者4381例 新增境外输入性新冠肺炎确诊病例11例 新增境外输入性无症状感染者1例 治愈出院28例
# https://wsjkw.sh.gov.cn/xwfb/20220328/910b5fe239e44c24a2ca95b4e6483877.html 上海2022年3月27日，新增本土新冠肺炎确诊病例50例 新增本土无症状感染者3450例 新增境外输入性新冠肺炎确诊病例10例 新增境外输入性无症状感染者4例 治愈出院37例
# https://wsjkw.sh.gov.cn/xwfb/20220327/d890a58b77654f1fac71dad84eedce4c.html 上海2022年3月26日，新增本土新冠肺炎确诊病例45例 新增本土无症状感染者2631例 新增境外输入性新冠肺炎确诊病例6例 新增境外输入性无症状感染者2例 治愈出院33例
# https://wsjkw.sh.gov.cn/xwfb/20220326/210fddd35d1248308b02acaa25950e09.html 上海2022年3月25日，新增本土新冠肺炎确诊病例38例 新增本土无症状感染者2231例 新增境外输入性新冠肺炎确诊病例9例 新增境外输入性无症状感染者2例 治愈出院21例  解除医学观察无症状感染者110例
# https://wsjkw.sh.gov.cn/xwfb/20220325/f2f2ffe5d70047c5bdc295baf6f211ec.html 上海2022年3月24日，新增本土新冠肺炎确诊病例29例 新增本土无症状感染者1580例 新增境外输入性新冠肺炎确诊病例12例 新增境外输入性无症状感染者5例 治愈出院63例  解除医学观察无症状感染者209例
# https://wsjkw.sh.gov.cn/xwfb/20220324/197cda6414014e408b25537f0fd8cd97.html 上海2022年3月23日，新增本土新冠肺炎确诊病例4例 新增本土无症状感染者979例 新增境外输入性新冠肺炎确诊病例10例 新增境外输入性无症状感染者3例 治愈出院81例  解除医学观察无症状感染者230例
# https://wsjkw.sh.gov.cn/xwfb/20220323/560de9823a914bda8e0fb31a7b91cccf.html 上海2022年3月22日，新增本土新冠肺炎确诊病例4例 新增本土无症状感染者977例 新增境外输入性新冠肺炎确诊病例10例 新增境外输入性无症状感染者4例 治愈出院23例  解除医学观察无症状感染者79例
# https://wsjkw.sh.gov.cn/xwfb/20220322/92cb33af745b4740be7edf66f086bad2.html 上海2022年3月21日，新增本土新冠肺炎确诊病例31例 新增本土无症状感染者865例 新增境外输入性新冠肺炎确诊病例8例 新增境外输入性无症状感染者3例 治愈出院140例  解除医学观察无症状感染者186例
# https://wsjkw.sh.gov.cn/xwfb/20220321/edd50169c9244fca9bf864013dc0da81.html 上海2022年3月20日，新增本土新冠肺炎确诊病例24例 新增本土无症状感染者734例 新增境外输入性新冠肺炎确诊病例17例 新增境外输入性无症状感染者2例 治愈出院44例  解除医学观察无症状感染者53例

# %%
print(all_confirmed_cases.group(1))
# Out:
# 24529

# %%
from requests_html import HTMLSession
import datetime
import pickle
import re


# home_addrs = ["https://wsjkw.sh.gov.cn/yqtb/index_3.html"]

def process_wp(c, dic):
    aeras = ['浦东新区', '黄浦区', '徐汇区', '长宁区', '静安区', '普陀区', '虹口区', '杨浦区', '闵行区', '宝山区', 
            '嘉定区', '金山区', '松江区', '青浦区', '奉贤区', '崇明区']
    
    for a in aeras:
        if c.startswith(a):
            dic[a] = []
            if not '居住于：' in c:
                continue
            locs = c.replace('，','').replace('。','').replace('、','').split('居住于：')[1].split('已对相关居住地落实终末消毒措施')[0].split('\n')
            dic[a] = []
            for loc in locs:
                if len(loc)>0:
                    dic[a].append(loc)
            return 
    return 



startdate = datetime.datetime.strptime('2022-3-19','%Y-%m-%d').date()
threshdate = datetime.datetime.strptime('2022-3-25','%Y-%m-%d').date()

session = HTMLSession()
home_addrs = ["http://wsjkw.sh.gov.cn/yqtb/", "https://wsjkw.sh.gov.cn/yqtb/index_2.html", "https://wsjkw.sh.gov.cn/yqtb/index_3.html"]

with open("data/location.pkl",'rb') as df:
    loc_data = pickle.load(df)

# loc_data = {}
    
for ha in home_addrs:
    session = HTMLSession()
    r = session.get(ha)
    items = r.html.find('ul.uli16', first=True).find('li')
    news = []
    for item in items:
        cur = item.find('a', first=True)
        href = cur.attrs['href']
        title = cur.attrs['title']
        
#         print (href, title)
        
        if not "居住地信息" in title:
            continue      
        
        date = re.search(r'\d+月\d+日', title).group(0)
        date = "2022-"+date.replace("日","").replace("月","-")
        print(date,href,title)
        dt = datetime.datetime.strptime(date,'%Y-%m-%d').date()
        
        if str(dt) in loc_data or dt <= startdate:
            break
        
        if href.startswith('/xwfb'):
            href = "https://wsjkw.sh.gov.cn"+href
        s = session.get(href)
        all_sections =  s.html.text
        all_sections = re.split('\d+年\d+月\d+日，',all_sections)
        
        dic = {}
        for sec in all_sections:
            process_wp(sec, dic)

#         print (dic['奉贤区'])
        loc_data[str(dt)] = dic
        

        
with open("data/location.pkl",'wb') as df:
    pickle.dump(loc_data, df)
# Out:
# 2022-4-13 https://mp.weixin.qq.com/s/L9AffT-SoEBV4puBa_mRqg 4月13日（0-24时）本市各区确诊病例、无症状感染者居住地信息
# 2022-4-12 https://mp.weixin.qq.com/s/OZGM-pNkefZqWr0IFRJj1g 【最新】4月12日（0-24时）本市各区确诊病例、无症状感染者居住地信息
# 2022-4-3 /xwfb/20220404/ff41c17c2bec4154b800f22040d3754a.html 4月3日（0-24时）本市各区确诊病例、无症状感染者居住地信息
# 2022-3-23 /xwfb/20220324/a8643ae53c7644f597cd88b8f2f4d8c4.html 3月23日（0-24时）本市各区确诊病例、无症状感染者居住地信息

# %%
today = set(loc_data['2022-04-15']['虹口区'])
yesterday = set(loc_data['2022-04-14']['虹口区'])
d2 = set(loc_data['2022-04-13']['虹口区'])
d3 = set(loc_data['2022-04-12']['虹口区'])
print (today)
print( yesterday)
print(d2,d3)
print (today - yesterday-d2)
print (len(today),len(yesterday),len(today-yesterday-d2-d3))
# Out:
# {'山阴路156弄', '新港路18号', '东余杭路210弄', '水电路737弄', '武进路242号', '黄渡路89弄', '横浜路63弄', '四川北路525号', '丰镇路2弄', '梧州路105号', '乍浦路344弄', '新嘉路1弄', '广粤路418号', '水电路831号', '东余杭路217号', '长春路304号', '虹镇老街269号', '文治路30弄', '沽源路107号', '广中三村', '虹湾路86弄', '花园路168弄', '文迁路38弄', '东余杭路181号', '四川北路1856弄', '宝安路160弄', '广中路525弄', '虹湾路545弄', '柳营路45弄', '长春路331弄', '新市南路1130弄', '溧阳路479号', '三门路750弄', '曲阳路630弄', '柳营路127弄', '溧阳路483号', '虹湾路288弄', '东余杭路111弄', '友谊二村', '保定路502弄', '四平路283号', '东江湾路580弄', '东余杭路15号', '昆明路181号', '虬江支路181号', '江杨南路55弄', '东余杭路869弄', '四平路480弄', '安国路263号', '梧州路109号', '唐山路577弄', '通州路188号', '同心路975弄', '商业一村', '辉河路51号', '溧阳路1203弄', '吴淞路560号', '株洲路258弄', '沙泾路166号', '凉城路480弄', '多伦路22号', '塘沽路401号', '溧阳路1156弄', '山阴路57弄', '赤峰路329号', '宝山路623号', '水电路1312弄', '东余杭路183号', '临平路46弄', '广中支路26号', '友谊新村', '东余杭路117号', '四川北路1999弄', '溧阳路473号', '惠民路260号', '四川北路1774弄', '万安路1213弄', '虹湾路55弄', '友谊三村', '欧阳路555弄', '溧阳路435号', '大连西路21号', '山阴路69弄', '东余杭路964号', '恒业路186号', '飞虹路187弄', '天宝路59弄', '临平路333号', '场中路755弄', '大连西路165弄', '花园路68弄', '东余杭路101弄', '东余杭路221弄', '保定路641号', '华严路228弄', '四川北路1604弄', '邮电新村44号', '丹徒路340弄', '梧州路299弄', '海伦路88弄', '西江湾路454弄', '飞虹路237弄', '东余杭路203号', '东余杭路65号', '纪念路500号', '广中路476号', '梧州路123号', '多伦路201弄', '临平路256弄', '四川北路818号', '哈尔滨路291号', '邮电新村47号', '西江湾路5号', '花园路5号', '华严路211弄', '广粤路289号', '广灵二村', '水电路541弄', '周家嘴路1063弄', '广中二村', '车站北路188弄', '凉城二村', '长春路348号', '瑞虹路233弄', '水电路1600弄', '四平路52弄', '华严路78号', '汶水东路717弄', '纪念路335弄', '东余杭路222号', '华昌路183弄', '昆山花园路5号', '东宝兴路753弄', '吴淞路407弄', '海伦路555弄', '山阴路168弄', '溧阳路489号', '东余杭路179号', '新市北路1361弄', '纪念路301号', '水电路810弄', '水电路1324弄', '逸仙路458弄', '运光路71弄', '奎照路789弄', '岳州路423弄', '新市南路1148弄', '梧州路107号', '辉河路40弄', '广中路366弄', '长春路365号', '新市南路690弄', '飞虹路369弄', '车站北路625弄', '飞虹支路57号', '花园路118弄', '水电路1119弄', '车站南路291弄', '广中路368弄', '瑞虹路25弄', '场中路390号', '四川北路1953弄', '乍浦路350号', '惠民路117弄', '东余杭路185号', '同心路990弄', '武昌路183弄', '横浜路75号', '岳州路399弄', '水电路1320弄', '广中五村', '四平路460弄', '梧州路99号', '广灵四路172弄', '梧州路121号', '溧阳路487号', '水电路818弄', '车站北路732弄', '高阳路168号', '邯郸路47号', '欧阳路679弄', '溧阳路311号', '梧州路83号', '东汉阳路309弄', '九龙路473号', '塘沽路300号', '大连西路159弄', '溧阳路445号', '沙泾路146号', '东江湾路188号', '通州路419弄', '溧阳路449号', '山阴路2弄', '长春路347号', '沽源路110弄', '建机新村', '山阴路85弄', '虹关路323弄', '霍山路86号', '广中路44号', '万安路669弄', '塘沽路330号', '虹关路123弄', '新港路69号', '广中路194弄', '大连西路13号', '瑞虹路30号', '曲阳路286号', '新市南路1215弄', '哈尔滨路52弄', '东宝兴路645弄', '恒业路129弄', '逸仙路1230弄', '祥德路124弄', '场中路32弄', '水电路261弄', '海伦路75号', '唐山路11号', '赤峰路370弄', '东余杭路910号', '场中路658号', '保定路20弄', '东余杭路175号', '周家嘴路1052号', '武进路577号', '东余杭路171号', '车站北路727弄', '海伦路118弄', '奎照路45号', '山阴路229弄', '场中路609弄', '广灵一村', '宝山路657号', '东余杭路1081号', '溧阳路471号', '横浜路45号', '昆山花园路3号', '虹湾路313弄', '宝山路888号', '海门路350弄', '梧州路139号', '东大名路501号', '广灵四路866弄', '沙泾路164号', '天宝路839号', '广粤路577弄', '东体育会路100弄', '昆明路73号', '山阴路165弄', '临平北路89弄', '梧州路103号', '银欣路38号', '三门路743弄', '祥德路39号', '场中路4弄', '东余杭路138号', '新市北路1508弄', '东余杭路21弄', '四川北路1906弄', '场中路787号', '长春路110号', '溧阳路493号', '四川北路1878号', '水电路1350号', '昆明路388弄', '中山北一路310弄', '曲阳路641号', '唐山路71号', '天通庵路666弄', '车站北路24弄', '海伦路188弄', '四平路621弄', '溧阳路429号', '物华路246弄', '汶水东路650弄', '天宝西路851弄', '安汾路780号', '邢家桥北路173弄', '车站北路500弄', '东余杭路212弄', '场中路360号', '欧阳路322号', '天宝西路251弄', '海门路609号', '安国路223弄', '花园路1086弄', '水电路380号', '塘沽路308弄', '东江湾路52弄', '奎照路647弄', '梧州路111号', '山阴路25弄', '广灵四路140弄', '水电路1381弄', '横浜路39号', '水电路1321弄', '广粤路1500弄', '同心路338弄', '场中路905弄', '多伦路236弄', '场中路312弄', '梧州路91号', '吴淞路335弄', '新市北路1525弄', '曲阳路620号', '东余杭路211弄', '飞虹路360弄', '吴淞路355弄', '长春路158弄', '梧州路125号', '凉城路55弄', '溧阳路115弄', '乍浦路307号', '仁德路420弄', '马厂路25号', '四平路311号', '东余杭路192号', '东长治路340弄', '新市南路579弄', '宝安路138弄', '瑞虹路368弄', '凉城路585弄', '保定路520弄', '吴家湾路136弄', '广中支路10弄', '榆林路93弄', '场中路842弄', '公平路369号', '梧州路87号', '汶水东路690弄', '临平路16弄', '水电路1661弄', '大连路975弄', '溧阳路1235号', '天宝路558弄', '逸仙路490弄', '沽源路111弄', '水电路108弄', '东余杭路220号', '溧阳路441号', '乍浦路354号', '万安路979弄', '周家嘴路1048号', '车站南路227号', '华严路68弄', '东余杭路6号', '奎照路11弄', '唐山路708弄', '多伦路1885号', '峨嵋路398号', '昆山路172弄', '四川北路2023弄', '广中路450号', '曲阳路487弄', '东余杭路147号', '吴家湾路52弄', '横浜路47号', '九龙路496号', '霍山路340号', '凉城路1201弄', '车站南路199号', '天宝西路2 ...
# {'欧阳路545弄', '多伦路75号', '凉城路126弄', '祥德路134号', '霍山路121号', '同丰路666号', '华昌路9号', '丹徒路78号', '黄渡路89弄', '西江湾路167弄', '华严路98弄', '沙泾路158号', '新嘉路1弄', '四川北路1946号', '广灵四路260号', '天水路191弄', '四平路421弄', '大连西路23号', '东体育会路443号', '文治路30弄', '广中三村', '虹湾路86弄', '花园路168弄', '逸仙路490号', '东大名路700号', '逸仙路432弄', '宝安路160弄', '昆山路174号', '柳营路45弄', '天宝西路242弄', '公平路469弄', '武昌路338号', '虹湾路288弄', '西江湾路760号', '宝安路145号', '黄渡路107弄', '虹关路88号', '四平路283号', '东汉阳路440号', '昆明路181号', '大连西路201弄', '长春路361号', '东余杭路869弄', '横浜路123弄', '四川北路85号', '海宁路55号', '海伦路805号', '唐山路577弄', '通州路188号', '西江湾路168号', '新市南路1141弄', '凉城路539弄', '天宝路358弄', '溧阳路1203弄', '四达路99弄', '高阳路669号', '公平路768弄', '吴淞路560号', '株洲路258弄', '四川北路856号', '海伦西路83号', '四川北路1898号', '瑞虹路28弄', '山阴路57弄', '水电路1312弄', '胡家木桥路41号', '广中支路26号', '新市南路1133弄', '蒋家桥路6号', '四川北路1972号', '四川北路1999弄', '同心路189弄', '九龙路575号', '虹湾路55弄', '华严路62号', '欧阳路555弄', '大连西路195弄', '逸仙路328号', '高阳路105号', '山阴路69弄', '四平路639号', '东余杭路964号', '飞虹路360号', '梧州路218弄', '大连西路165弄', '奎照路791弄', '海宁路358号', '丹徒路213弄', '九龙路515号', '四川北路199弄', '马厂路825号', '周家嘴路850弄', '长春路336号', '万安路978号', '丹徒路340弄', '衡水路89弄', '梧州路299弄', '海伦路88弄', '广灵四路561弄', '纪念路500号', '闵行路181号', '车站西路300弄', '韶嘉路51弄', '多伦路201弄', '临平路256弄', '四川北路1274号', '株洲路399弄', '保定路125号', '四川北路127号', '曲阳路592号', '临平北路60弄', '欧阳路669号', '多伦路66号', '昆山路160号', '塘沽路219号', '水电路541弄', '周家嘴路1063弄', '四川北路75号', '黄渡路65号', '场中路187弄', '凉城路500弄', '欧阳路196号', '车站北路132弄', '天宝路902号', '长春路348号', '飞虹路600弄', '乍浦路324号', '水电路1600弄', '四川北路1926号', '四平路52弄', '虹镇老街251弄', '吴淞路407弄', '仁德路400弄', '天通庵路788号', '水电路1324弄', '昆山路106号', '周家嘴路887号', '唐山路163号', '海宁路307号', '新市南路1148弄', '岳州路423弄', '四平路372号', '同心路363弄', '同心路116弄', '花园路118弄', '飞虹支路57号', '四平路643号', '广粤路1601弄', '吴淞路299弄', '华严路58弄', '四川北路1953弄', '新港路311弄', '乍浦路350号', '东宝兴路258弄', '惠民路117弄', '大连西路215弄', '祥德路468号', '广中五村', '多伦路52号', '中山北一路865弄', '横浜路43号', '东横浜路51号', '水电路818弄', '天宝路73号', '四平路753号', '东汉阳路389号', '瑞虹路438弄', '万安路1213号', '四平路641号', '东汉阳路309弄', '塘沽路300号', '东横浜路53号', '同心路209弄', '通州路419弄', '辉河路118弄', '虹关路323弄', '新市北路140号', '长山路577弄', '纪念路494弄', '万安路669弄', '广中路194弄', '通州路423号', '密云路295号', '新市南路1215弄', '新市南路1153弄', '恒业路129弄', '新市北路1501弄', '逸仙路1230弄', '伊敏河路99弄', '曲阳路385弄', '沽源路113弄', '场中路32弄', '水电路261弄', '海伦路75号', '赤峰路370弄', '场中路658号', '海宁路5号', '塘沽路322号', '保定路20弄', '昆明路100号', '新市南路845号', '万安路600弄', '大连西路615号', '溧阳路501号', '山阴路229弄', '宝山路657号', '东大名路1171号', '舟山路157弄', '虹湾路313弄', '西江湾路476弄', '凉城路1188弄', '天宝路839号', '广粤路577弄', '东余杭路815号', '东体育会路100弄', '银欣路38号', '三门路743弄', '四川北路1941弄', '纪念路335号', '场中路4弄', '宝安支路51号', '长春路343号', '瑞虹路383弄', '大连西路25号', '新市北路1508弄', '丹徒路377号', '四川北路1906弄', '新市南路1137弄', '玉田新村', '场中路787号', '祥德路34号', '邮电新村', '广中路680弄', '水电路1350号', '东余杭路978号', '大连西路199号', '中山北一路310弄', '吉祥路88号', '天通庵路666弄', '安国路76号', '宝安支路85号', '海伦路188弄', '广中路562号', '四平路621弄', '天宝路181弄', '物华路246弄', '汶水东路650弄', '邯郸路39号', '大连西路257弄', '中山北一路131弄', '黄渡路103弄', '天宝西路251弄', '东宝兴路747号', '安国路223弄', '广灵一路52号', '商业二村', '车站南路39号', '四平路581号', '万安路960号', '东体育会路119弄', '武进路96号', '乍浦路313弄', '武进路85号', '惠民路95号', '水电路1381弄', '东余杭路214号', '东余杭路218号', '海宁路137号', '瑞虹路8弄', '大连西路11号', '天宝西路241弄', '水电路1321弄', '广粤路1500弄', '昆山路259号', '同心路338弄', '同心路1号', '欧阳路331号', '中山北一路1250号', '吴淞路355弄', '乍浦路307号', '四川北路1746号', '昆山路108弄', '仁德路420弄', '四平路311号', '东长治路340弄', '商丘路250号', '大连西路153号', '岳州路50号', '保定路520弄', '广中支路10弄', '玉田支路4号', '场中路842弄', '临平路16弄', '四川北路1885号', '曲阳路69弄', '曲阳路851弄', '大连路975弄', '四川北路1545弄', '东长治路299弄', '四川北路1932号', '四川北路1960号', '水电路108弄', '万安路979弄', '通州路392弄', '周家嘴路338弄', '四达路25弄', '通州路415弄', '同心路125弄', '唐山路708弄', '大连西路157号', '峨嵋路398号', '昆山路172弄', '四川北路2023弄', '山阴路325号', '吴家湾路52弄', '九龙路496号', '凉城路1201弄', '吴淞路108弄', '金山路43号', '新市南路515弄', '新市南路1149弄', '凉城路465弄', '东大名路888弄', '天宝西路5弄', '新市北路1400号', '三门路759弄', '场中路41号', '四川北路1851号', '昆明路80弄', '周家嘴路981弄'}
# {'吉祥路38弄', '惠民路254号', '欧阳路545弄', '车站南路406弄', '山阴路156弄', '海宁路100号', '同心路1035弄', '宝山路625号', '东宝兴路306号', '四川北路25号', '梧州路289号', '水电路737弄', '宝安支路79弄', '池沟路62弄', '东体育会路659弄', '车站北路400弄', '塘沽路567号', '丹徒路78号', '黄渡路89弄', '场中路916弄', '横浜路63弄', '丰镇路2弄', '邢家桥南路61号', '东体育会路705号', '华严路98弄', '商洛小区', '万安路409弄', '西宝兴路949弄', '乍浦路344弄', '赤峰路301号', '东宝兴路71号', '北宝兴路71号', '安国路285号', '四平路421弄', '广中路620弄', '文治路30弄', '沽源路107号', '广中三村', '旅顺路199弄', '东大名路700号', '惠民路238号', '文迁路38弄', '四川北路1856弄', '宝安路160弄', '海门路630号', '玉田路500号', '东大名路1075号', '天宝西路242弄', '长春路331弄', '临潼西村', '新市南路1130弄', '三门路750弄', '周家嘴路368号', '曲阳路630弄', '武昌路338号', '吉祥路84弄', '虹湾路288弄', '宝安路145号', '友谊二村', '恒业路118弄', '黄渡路107弄', '玉田路311弄', '四平路283号', '唐山路19号', '大连西路201弄', '长春路361号', '虬江支路181号', '江杨南路55弄', '东余杭路869弄', '飞虹支路237弄', '同心路3号', '华严路244号', '四川北路85号', '海宁路55号', '唐山路577弄', '通州路188号', '武东路28弄', '同丰路666弄', '嘉兴路213号', '飞虹路25弄', '商业一村', '天宝路358弄', '车站西路305弄', '花园路76弄', '四达路99弄', '吴家湾路215号', '公平路768弄', '株洲路258弄', '长春路158号', '凉城路480弄', '东长治路665弄', '玉田路446弄', '溧阳路1156弄', '山阴路57弄', '宝安支路10号', '凉城路847弄', '宝山路623号', '百官街21号', '水电路1312弄', '临平路46弄', '赤峰路471弄', '宝安路155号', '新市南路1133弄', '武进路288弄', '榆林路43弄', '四川北路1999弄', '同心路189弄', '惠民路118弄', '九龙路441号', '丰镇路14弄', '万安路1213弄', '四川北路1774弄', '天潼路508号', '保定路358号', '虹湾路55弄', '天潼路528号', '新市北路139弄', '欧阳路555弄', '塘沽路309号', '大连西路195弄', '东大名路999号', '大连西路21号', '新市北路1505号', '高阳路105号', '山阴路69弄', '昆山路206号', '四平路639号', '榆林路114弄', '大连西路169号', '逸仙路58号', '九龙路475号', '西江湾路700弄', '四平路12号', '长春路353号', '飞虹路187弄', '东余杭路1320号', '东余杭路833号', '梧州路218弄', '天潼路328号', '临平路333号', '场中路755弄', '海伦西路30弄', '大连西路165弄', '祥德路355号', '丹徒路337号', '九龙路515号', '四平路780弄', '同心路159号', '四川北路1604弄', '长春路336号', '武昌路258号', '衡水路89弄', '大连西路128号', '飞虹路237弄', '闵行路181号', '峨嵋路366弄', '四川北路88号', '韶嘉路51弄', '赤峰路445号', '多伦路201弄', '临平路256弄', '四川北路1274号', '四川北路818号', '株洲路399弄', '保定路125号', '太平桥支路8号', '通州路88弄', '溧阳路1084弄', '塘沽路219号', '多伦路163弄', '广灵二村', '周家嘴路1063弄', '东体育会路115弄', '四川北路75号', '玉田路415号', '四川北路1515弄', '大连西路241弄', '丰镇路300号', '场中路187弄', '曲阳路820弄', '四平路97弄', '舟山路805弄', '株洲路299弄', '东汉阳路499弄', '车站北路188弄', '四平路114弄', '丰镇路66号', '凉城二村', '曲阳路551号', '天宝路902号', '凉城路139弄', '临平北路256弄', '梧州路5号', '逸仙路270号', '唐山路410号', '大连西路261号', '黄浦路53号', '欧阳路327号', '长春路348号', '同心路963号', '长春路58弄', '同丰路718号', '汶水东路717弄', '四川北路1926号', '四平路52弄', '三门路728弄', '昆山花园路5号', '新市南路1100弄', '同心路133弄', '吴淞路407弄', '仁德路400弄', '海伦路555弄', '水电路191弄', '纪念路555弄', '物华路73号', '吴淞路44号', '逸仙路458弄', '甜爱路331弄', '唐山路163号', '海宁路307号', '新市南路1148弄', '岳州路423弄', '昆山路136弄', '丰镇路100号', '中山北一路3718弄', '天宝路256弄', '文迁路25弄', '西江湾路1368弄', '西江湾路168弄', '天通庵路683号', '车站北路625弄', '飞虹支路57号', '水电路1119弄', '广中路558号', '纪念路550弄', '广粤路1601弄', '东余杭路1336弄', '东宝兴路312号', '瑞虹路25弄', '场中路390号', '四川北路1953弄', '东宝兴路461弄', '东宝兴路258弄', '惠民路117弄', '飞虹支路83弄', '恒业路365弄', '同心路990弄', '横浜路75号', '岳州路399弄', '东余杭路827号', '大连西路215弄', '东江湾路221号', '广中五村', '横浜路43号', '水电路120号', '同心路1115弄', '东宝兴路475号', '横浜路35弄', '车站北路732弄', '海伦西路55号', '惠民路133弄', '安国路56号', '四平路753号', '宝山路621号', '东汉阳路338弄', '四平路641号', '东汉阳路309弄', '东余杭路1025弄', '塘沽路300号', '大连西路161号', '同心路209弄', '沙泾路146号', '通州路419弄', '西江湾路89号', '山阴路2弄', '吴淞路35弄', '新港路190弄', '新广路251弄', '万寿街23弄', '建机新村', '大连西路145弄', '川公路176弄', '物华路113弄', '天通庵路581号', '昆山路103弄', '万安路669弄', '邢家桥南路253弄', '溧阳路1203号', '通州路123号', '车站南路407弄', '临平路133弄', '乍浦路425号', '嘉兴路337弄', '天通庵路553弄', '东余杭路1363号', '东大名路568号', '新市北路1501弄', '曲阳路385弄', '天通庵路580号', '唐山路778弄', '场中路658号', '海宁路5号', '保定路20弄', '赤峰路404弄', '北苏州路400号', '车站北路727弄', '虹湾路59号', '福德路11号', '东长治路588号', '三门路719弄', '保定路1063号', '东余杭路225号', '宝山路657号', '塘沽路646弄', '大连西路29号', '凉城路815弄', '吴淞路205号', '武进路289号', '中州路123号', '周家嘴路807号', '虹湾路313弄', '东横浜路47号', '广灵四路866弄', '保定路299弄', '广粤路577弄', '东体育会路100弄', '银欣路38号', '西宝兴路99弄', '东余杭路1168号', '东宝兴路439号', '虬江路49弄', '凉城一村', '场中路4弄', '宝安支路51号', '大连西路25号', '丹徒路377号', '四川北路1906弄', '玉田新村', '场中路787号', '邮电新村', '柳营路125号', '广中路680弄', '宝安支路83号', '昆明路388弄', '中山北一路310弄', '高阳路553号', '天通庵路666弄', '安国路76号', '车站北路24弄', '新港路24号', '广中路390号', '新市南路918弄', '长阳路288号', '东体育会路437号', '株洲路9弄', '四平路621弄', '东宝兴路254弄', '四川北路1941号', '车站西路303弄', '赤峰路335号', '水 ...
# {'九龙路473号', '水电路380号', '花园路1086弄', '塘沽路308弄', '东江湾路52弄', '大连西路159弄', '新港路18号', '东余杭路221弄', '保定路641号', '溧阳路445号', '东江湾路188号', '华严路228弄', '溧阳路449号', '东余杭路210弄', '长春路347号', '邮电新村44号', '武进路242号', '梧州路111号', '沽源路110弄', '西江湾路454弄', '东余杭路203号', '东余杭路65号', '山阴路85弄', '广中路476号', '山阴路25弄', '梧州路123号', '广灵四路140弄', '霍山路86号', '四川北路525号', '哈尔滨路291号', '邮电新村47号', '广中路44号', '梧州路105号', '西江湾路5号', '塘沽路330号', '虹关路123弄', '新港路69号', '横浜路39号', '广粤路418号', '大连西路13号', '瑞虹路30号', '花园路5号', '水电路831号', '华严路211弄', '东余杭路217号', '场中路905弄', '梧州路91号', '多伦路236弄', '场中路312弄', '新市北路1525弄', '广粤路289号', '长春路304号', '虹镇老街269号', '曲阳路286号', '广中二村', '东余杭路181号', '长春路158弄', '梧州路125号', '哈尔滨路52弄', '凉城路55弄', '东宝兴路645弄', '广中路525弄', '溧阳路115弄', '虹湾路545弄', '祥德路124弄', '花园路68弄', '马厂路25号', '溧阳路479号', '东余杭路192号', '唐山路11号', '新市南路579弄', '柳营路127弄', '东余杭路910号', '溧阳路483号', '瑞虹路368弄', '东余杭路111弄', '凉城路585弄', '周家嘴路1052号', '东余杭路175号', '武进路577号', '吴家湾路136弄', '东余杭路171号', '保定路502弄', '海伦路118弄', '瑞虹路233弄', '奎照路45号', '公平路369号', '华严路78号', '场中路609弄', '广灵一村', '东江湾路580弄', '东余杭路15号', '梧州路87号', '纪念路335弄', '东余杭路222号', '水电路1661弄', '华昌路183弄', '东余杭路1081号', '东宝兴路753弄', '四平路480弄', '溧阳路471号', '横浜路45号', '昆山花园路3号', '宝山路888号', '海门路350弄', '梧州路139号', '安国路263号', '梧州路109号', '东大名路501号', '同心路975弄', '山阴路168弄', '溧阳路489号', '东余杭路179号', '沙泾路164号', '天宝路558弄', '逸仙路490弄', '昆明路73号', '新市北路1361弄', '山阴路165弄', '纪念路301号', '水电路810弄', '临平北路89弄', '辉河路51号', '梧州路103号', '溧阳路441号', '运光路71弄', '乍浦路354号', '祥德路39号', '奎照路789弄', '东余杭路138号', '梧州路107号', '东余杭路21弄', '沙泾路166号', '塘沽路401号', '多伦路22号', '辉河路40弄', '长春路110号', '溧阳路493号', '广中路366弄', '赤峰路329号', '长春路365号', '四川北路1878号', '车站南路227号', '新市南路690弄', '飞虹路369弄', '东余杭路183号', '东余杭路6号', '曲阳路641号', '车站南路291弄', '友谊新村', '东余杭路117号', '唐山路71号', '广中路368弄', '广中路450号', '溧阳路429号', '东余杭路147号', '横浜路47号', '溧阳路473号', '霍山路340号', '惠民路260号', '友谊三村', '东余杭路185号', '武昌路183弄', '溧阳路435号', '水电路1320弄', '车站南路199号', '天宝西路252弄', '天宝西路851弄', '四平路460弄', '梧州路99号', '安汾路780号', '邢家桥北路173弄', '周家嘴路186号', '恒业路186号', '广灵四路172弄', '梧州路121号', '水电路1421弄', '溧阳路487号', '同心路28弄', '东余杭路66号', '东余杭路212弄', '四川北路1174弄', '新市南路1100号', '场中路360号', '欧阳路322号', '天宝路59弄', '高阳路168号', '邯郸路47号', '欧阳路679弄', '溧阳路311号', '海门路609号', '梧州路83号', '宝安支路81号', '东余杭路101弄', '东宝兴路272弄'}
# 377 330 171

# %%
print(yesterday_locs)
print(sum(total_list))
print(1.0*(yesterday_locs-sum(total_list))/yesterday_locs)

tmp = 0.0
for i in range(1,5):
    tmp+=(1.0*total_list[i]/yesterday_locs)
    
print (tmp, 1-tmp)

print(res)
# Out:
# 6300
# 3991
# 0.3665079365079365
# 0.6334920634920634 0.36650793650793656
# [[0.1808585503166784, 0.4574961360123647, 0.3435897435897436, 0.39634146341463417, 0.5607476635514019, 0.4089068825910932, 0.5105263157894737, 0.4345549738219896, 0.392079207920792, 0.3741379310344828, 0.44277108433734946, 0.44999999999999996, 0.4199475065616798, 0.3705357142857143, 0.4285714285714286, 0.5, 0.3665079365079365], [0.573539760731879, 0.0015455950540958269, 0.3282051282051282, 0.39634146341463417, 0.2523364485981308, 0.26720647773279355, 0.11578947368421053, 0.35951134380453753, 0.37425742574257426, 0.49137931034482757, 0.20783132530120482, 0.1, 0.2440944881889764, 0.39732142857142855, 0.3333333333333333, 0.3333333333333333, 0.3458730158730159], [0.18508092892329345, 0.4605873261205564, 0.26495726495726496, 0.10365853658536585, 0.1261682242990654, 0.17813765182186234, 0.3105263157894737, 0.16404886561954624, 0.14455445544554454, 0.07931034482758621, 0.26506024096385544, 0.4, 0.2650918635170604, 0.20535714285714285, 0.19047619047619047, 0.16666666666666666, 0.2195238095238095], [0.054187192118226604, 0.06491499227202473, 0.05299145299145299, 0.10365853658536585, 0.056074766355140186, 0.11336032388663968, 0.05, 0.038394415357766144, 0.0594059405940594, 0.04827586206896552, 0.060240963855421686, 0.0, 0.07086614173228346, 0.026785714285714284, 0.0, 0.0, 0.056984126984126984], [0.0063335679099225895, 0.015455950540958269, 0.010256410256410256, 0.0, 0.004672897196261682, 0.032388663967611336, 0.013157894736842105, 0.0034904013961605585, 0.0297029702970297, 0.006896551724137931, 0.024096385542168676, 0.05, 0.0, 0.0, 0.047619047619047616, 0.0, 0.011111111111111112]]

# %%
print(all_data['2022-04-15']['Asymptomatic']['Out_control']['虹口区'])
# Out:
# 3

# %%
import re
import datetime
from requests_html import HTMLSession

def process_content_type1(c, dic):
    if "入关" in c:
        return
    
    if  c.startswith("无症状感染者"):
        content_type = "Asymptomatic"
        mark_content = "无症状感染者"
    elif c.startswith("病例"):
        content_type = "ConfirmedCases"
        mark_content = "病例"
    else:
        return 
    
    if "本市闭环隔离管控人员" in c:
        control_type = "In_control"
    elif "为此前报告的本土无症状感染者" in c:
        control_type = "FromAsymptomatic"
    else:
        control_type = "Out_control"
        
    if not content_type in dic:
        dic[content_type] = {}
    if not control_type in dic[content_type]:
        dic[content_type][control_type] = {}
        
    c = c.split("，")
    
    for i in range(len(c)>>1):
        if c[2*i].startswith(mark_content):
            patients = c[2*i].split('—')
            
            if len(patients) == 2:
                s = int(patients[0][len(mark_content):])
                if patients[1].startswith(mark_content):
                    e = int(patients[1][len(mark_content):])
                else:
                    e = int(patients[1])
                num = e-s+1
            elif "、" in c[2*i]:
                num = len(c[2*i].split("、" ))
            else:
                num = 1
        
            addr = c[2*i+1][3:]
            dic[content_type][control_type][addr] = num

        else:
            break    
    return

def process_wp(c, dic):
    aeras = ['浦东新区', '黄浦区', '徐汇区', '长宁区', '静安区', '普陀区', '虹口区', '杨浦区', '闵行区', '宝山区', 
            '嘉定区', '金山区', '松江区', '青浦区', '奉贤区', '崇明区']
    
    for a in aeras:
        if c.startswith(a):
            dic[a] = []
            if not '居住于：' in c:
                continue
            locs = c.replace('，','').replace('。','').replace('、','').split('居住于：')[1].split('已对相关居住地落实终末消毒措施')[0].split('\n')
            dic[a] = []
            for loc in locs:
                if len(loc)>0:
                    dic[a].append(loc)
            return 
    return 


def add_data_from_href(href):
    session = HTMLSession()
    r = session.get(href)
    txt = r.html.xpath('//*[@id="activity-name"]',first=True).text
    
    sections = txt.split('\n\n')
    
    date = re.search(r'\d+月\d+日', sections[0]).group(0)
    date = "2022-"+date.replace("日","").replace("月","-")
    print(date)
    dt = datetime.datetime.strptime(date,'%Y-%m-%d').date()
    
    dic = {}
    for sec in sections:
        process_content_type1(sec.replace('\n',''), dic)
    
    
        all_confirmed_cases = re.search(r'累计本土确诊(\d+)例', sec)

        if all_confirmed_cases:
            dic['all_confirmed_cases'] = all_confirmed_cases.group(1)
        else:
            continue

        all_cured_cases = re.search(r'治愈出院(\d+)例', sec)
        if all_cured_cases:
            dic['all_cured_cases'] = all_cured_cases.group(1)

        all_in_treatment= re.search(r'在院治疗(\d+)例', sec)
        if all_in_treatment:
            dic['all_in_treatment'] = all_in_treatment.group(1)

        all_critical_cases = re.search(r'其中重症(\d+)例', sec)
        if all_critical_cases:
            dic['all_critical_cases'] = all_critical_cases.group(1)

        all_in_observation = re.search(r'现有待排查的疑似病例(\d+)例', sec)
        if all_in_observation:
            dic['all_in_observation'] = all_in_observation.group(1)

        all_deaths =  re.search(r'死亡(\d+)例', sec)
        if all_deaths:
            dic['all_deaths'] = all_deaths.group(1)
        
    return dt, dic

def add_loc_from_href(href):
    session = HTMLSession()
    s = session.get(href)
    txt = s.html.xpath('//*[@id="page-content"]',first=True).text
    
    title = txt.split('\n')[0]
    
    print(title)
    
    date = re.search(r'\d+月\d+日', title).group(0)
    date = "2022-"+date.replace("日","").replace("月","-")
    print(date)
    dt = datetime.datetime.strptime(date,'%Y-%m-%d').date()
    
    all_sections = re.split('\d+年\d+月\d+日，',txt)

    dic = {}
    for sec in all_sections:
        process_wp(sec, dic)
    
    return dt, dic

# %%
import pickle

with open("data/location.pkl",'rb') as df:
    loc_data = pickle.load(df)
    
with open("data/all.pkl",'rb') as df:
    all_data = pickle.load(df)
    
date, data = add_data_from_href('https://mp.weixin.qq.com/s/9VrtdzjAQC-3rvgokmGmBg')
if not str(date) in all_data:
    all_data[str(date)] = data
    
    with open("data/all.pkl",'wb') as df:
        pickle.dump(all_data, df)
    
date, loc = add_loc_from_href('https://mp.weixin.qq.com/s/puNUP9bjYlZNELsse09Z0w')
if not str(date) in loc_data:
    loc_data[str(date)] = loc
    
    with open("data/location.pkl",'wb') as df:
        pickle.dump(loc_data, df)
# Out:
# 2022-4-19
# 4月19日（0-24时）本市各区确诊病例、无症状感染者居住地信息
# 2022-4-19

# %%
import pyecharts.options as opts
from pyecharts.charts import Line, Page, Bar, Pie

startdate = datetime.datetime.strptime('2022-3-19','%Y-%m-%d').date()

def draw_graph(data, addrs, content_types, control_types, title, sum=False, mark=False):
    dt = startdate
    y_data = [[] for i in range(len(addrs))]
    x_data = []
    if sum:
        y_data.append([])
    while dt != datetime.date.today():
        if not str(dt) in data:
            dt += datetime.timedelta(days=1)
            continue
        data_for_one_day = data[str(dt)]
        sum_for_one_day = 0
        for i in range(len(addrs)):
            cur = 0
            for ti in content_types:
                if not ti in data_for_one_day:
                    continue
                for tj in control_types:
                    if not tj in data_for_one_day[ti]:
                        continue
                    if addrs[i] == "非浦东":
                        for key in data_for_one_day[ti][tj]:
                            if not "浦东" in key:
                                cur += data_for_one_day[ti][tj][key]
                        continue
                    if addrs[i] in data_for_one_day[ti][tj]:
                        cur += data_for_one_day[ti][tj][addrs[i]]
        
            y_data[i].append(cur)
            sum_for_one_day += cur
        
        if sum:
            y_data[-1].append(sum_for_one_day)
        
        x_data.append(str(dt))
            
        dt += datetime.timedelta(days=1)
        
    line = Line()
    line.add_xaxis(xaxis_data=x_data)
    for i in range(len(addrs)):
        if mark:
            line.add_yaxis(
                series_name=addrs[i],
                y_axis=y_data[i],
                is_smooth=True,
#                 markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_='max')]),
                markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(type_='max')])
            )
        else:
            line.add_yaxis(
                series_name=addrs[i],
                y_axis=y_data[i],
                is_smooth=True
            )
#         print(y_data[i])
    if sum:
        if mark:
            line.add_yaxis(
                series_name="总计",
                y_axis=y_data[-1],
                is_smooth=True,
#                 markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_='max')]),
                markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(type_='max')])
            )
        else:
            line.add_yaxis(
                series_name="总计",
                y_axis=y_data[-1],
                is_smooth=True
            )
    
    pl = 50-len(title)    
    line.set_global_opts(title_opts=opts.TitleOpts(title=title,pos_bottom='bottom',pos_left=str(pl)+'%'))
    #line.render(title+".html")
#     print(type(line))
    return line

name_map = {'all_confirmed_cases':'累计确诊病例','all_cured_cases':'累计治愈病例','all_in_treatment':'在院治疗病例','all_deaths':'累计死亡病例'}
def draw_culmulative(data, title, keys=['all_confirmed_cases','all_cured_cases','all_in_treatment','all_deaths']):
    dt = startdate
    y_data = [[] for i in range(len(keys))]
    x_data = []

    while dt != datetime.date.today():
        if not str(dt) in data:
            dt += datetime.timedelta(days=1)
            continue
        data_for_one_day = data[str(dt)]
        
        for i in range(len(keys)):
            if keys[i] in data_for_one_day:
                y_data[i].append(data_for_one_day[keys[i]])
            else:
                y_data[i].append(0)
                
        x_data.append(str(dt))
        dt += datetime.timedelta(days=1)
        
    line = Line()
    line.add_xaxis(xaxis_data=x_data)
    for i in range(len(keys)):
        line.add_yaxis(
            series_name=name_map[keys[i]],
            y_axis=y_data[i],
            is_smooth=True
        )
    pl = 50-len(title)    
    line.set_global_opts(title_opts=opts.TitleOpts(title=title,pos_bottom='bottom',pos_left=str(pl)+'%'))
    return line
        
def draw_pie(data, title):
    all_date = [datetime.datetime.strptime(d,'%Y-%m-%d').date() for d in data.keys()]
    latest = max(all_date)
    
    data_for_today = data[str(latest)]
    attr = ['累计治愈', '在院治疗(轻)', '在院治疗(重)', '累计死亡']
    
    
    all_confirmed_cases = 0
    if 'all_confirmed_cases' in  data_for_today:
        all_confirmed_cases = int(data_for_today['all_confirmed_cases'])
    
    all_in_treatment = 0
    if 'all_in_treatment' in  data_for_today:
        all_in_treatment = int(data_for_today['all_in_treatment'])
        
    all_cured_cases = 0
    if 'all_cured_cases' in  data_for_today:
        all_cured_cases = int(data_for_today['all_cured_cases'])
    
    all_critical_cases = 0
    if 'all_critical_cases' in  data_for_today:
        all_critical_cases = int(data_for_today['all_critical_cases'])
        
    all_deaths = 0
    if 'all_deaths' in  data_for_today:
        all_deaths = int(data_for_today['all_deaths'])
        
    v1 = [all_cured_cases, all_in_treatment-all_critical_cases, all_critical_cases, all_deaths]
    
    print (data_for_today)
    
    pie = Pie()
    pie.add('', [list(z) for z in zip(attr, v1)])
    pl = 50-len(title)    
    pie.set_global_opts(title_opts=opts.TitleOpts(title=title,pos_bottom='bottom',pos_left=str(pl)+'%'))
    return pie

daily_increase_summary = draw_graph(all_data, ['浦东新区', '非浦东'], 
          ['Asymptomatic','ConfirmedCases'],['In_control','Out_control','FromAsymptomatic'],"每日新增无症状+确诊概览", True, True)


daily_out_control_increase_summary = draw_graph(all_data, ['浦东新区', '非浦东'], 
          ['Asymptomatic','ConfirmedCases'],['Out_control'],"管控区外每日新增无症状+确诊概览", True, True)

Change_daily_increase = draw_graph(all_data, ['浦东新区', '黄浦区', '徐汇区', '长宁区', '静安区', 
                      '普陀区', '虹口区', '杨浦区', '闵行区', '宝山区', 
                      '嘉定区', '金山区', '松江区', '青浦区', '奉贤区', '崇明区'], 
          ['Asymptomatic','ConfirmedCases'],['FromAsymptomatic'],"无症状转归",True)

all_daily_increase = draw_graph(all_data, ['浦东新区', '黄浦区', '徐汇区', '长宁区', '静安区', 
                      '普陀区', '虹口区', '杨浦区', '闵行区', '宝山区', 
                      '嘉定区', '金山区', '松江区', '青浦区', '奉贤区', '崇明区'], 
          ['Asymptomatic','ConfirmedCases'],['In_control','Out_control','FromAsymptomatic'],"各区每日新增无症状+确诊病例")

Out_daily_increase = draw_graph(all_data, ['浦东新区', '黄浦区', '徐汇区', '长宁区', '静安区', 
                      '普陀区', '虹口区', '杨浦区', '闵行区', '宝山区', 
                      '嘉定区', '金山区', '松江区', '青浦区', '奉贤区', '崇明区'], 
          ['Asymptomatic','ConfirmedCases'],['Out_control'],"各区管控区外每日新增无症状+确诊病例")

daily_increase_summary_only_positive = draw_graph(all_data, ['浦东新区', '非浦东'], 
          ['ConfirmedCases'],['In_control','Out_control','FromAsymptomatic'],"每日新增确诊病例概览", True, True)

daily_out_control_increase_summary_only_positive = draw_graph(all_data, ['浦东新区', '非浦东'], 
          ['ConfirmedCases'],['Out_control'],"管控区外每日新增确诊病例概览", True, True)

daily_increase_summary_only_asymptomatic = draw_graph(all_data, ['浦东新区', '非浦东'], 
          ['Asymptomatic'],['In_control','Out_control','FromAsymptomatic'],"每日新增无症状病例概览", True, True)

daily_out_control_increase_summary_only_asymptomatic = draw_graph(all_data, ['浦东新区', '非浦东'], 
          ['Asymptomatic'],['Out_control'],"管控区外每日新增无症状病例概览", True, True)

cumulative1 = draw_culmulative(all_data, title='累计病例数')
pie = draw_pie(all_data, title='本土累计病例分布')

# with open("data/location.pkl",'rb') as df:
#     loc_data = pickle.load(df)

aeras_map = {'浦东新区':0, '黄浦区':1, '徐汇区':2, '长宁区':3, '静安区':4, '普陀区':5, '虹口区':6, '杨浦区':7, '闵行区':8, '宝山区':9, 
            '嘉定区':10, '金山区':11, '松江区':12, '青浦区':13, '奉贤区':14, '崇明区':15}

# aeras_map = { '奉贤区':0}

all_date = [datetime.datetime.strptime(d,'%Y-%m-%d').date() for d in loc_data.keys()]
latest = max(all_date)
earliest = min(all_date)

locsets = []
for k in range(len(aeras_map)+1):
    locsets.append([set() for i in range(5)])

    
sd = earliest
while not sd == latest:
    if not str(sd) in loc_data:
        sd = sd + datetime.timedelta(days=1)
        continue
    
    data_for_one_day = loc_data[str(sd)]
    duration = (latest - sd).days

    for area in aeras_map:
        if area in data_for_one_day:
            if duration > 14:
                locsets[aeras_map[area]][-1] = locsets[aeras_map[area]][-1] | set(data_for_one_day[area])
            elif duration > 7:
                locsets[aeras_map[area]][-2] = locsets[aeras_map[area]][-2] | set(data_for_one_day[area])
            elif duration > 4:
                locsets[aeras_map[area]][-3] = locsets[aeras_map[area]][-3] | set(data_for_one_day[area])
            else:
                locsets[aeras_map[area]][-4] = locsets[aeras_map[area]][-5] | set(data_for_one_day[area])
    
    sd = sd + datetime.timedelta(days=1)
    
for area in aeras_map:
    for i in range(1,5):
        for j in range(i):
            locsets[aeras_map[area]][i] = locsets[aeras_map[area]][i] - locsets[aeras_map[area]][j]

            
    
loc_latest = loc_data[str(latest)]
total_list = [0 for i in range(5)]
yesterday_locs = 0

res = [[0.0 for i in range(len(aeras_map)+1)] for j in range(5)]

for area in aeras_map:
    old_places = 0.0
    
    if area in loc_latest:
        count = len(loc_latest[area])
        if count == 0:
            continue
        yesterday_locs += count
        for i in range(1,5):
            tmp = set(loc_latest[area]) & locsets[aeras_map[area]][i]
            res[i][aeras_map[area]] = 1.0* len(tmp) / count
            old_places += res[i][aeras_map[area]]
            total_list[i] += len(tmp)
            
    res[0][aeras_map[area]] = 1 - old_places
    
if yesterday_locs>0:
    for i in range(1,5):
        res[i][-1] = 1.0*total_list[i]/yesterday_locs
    res[0][-1] = 1.0*(yesterday_locs-sum(total_list))/yesterday_locs

# for i in range(len(res)):
#     print(i, res[i])
    
bar = Bar()
xaxis = list(aeras_map.keys())
xaxis.append('总计')
bar.add_xaxis(xaxis)

ytitles = ['新增阳性小区','四日有新增','四日无新增','七日无新增','十四日无新增']

for i in range(5):
    bar.add_yaxis(ytitles[i], res[i], stack='stack1')

bar_title = str(latest)+"阳性小区分布"
pl = 50-len(bar_title)   
bar.set_global_opts(title_opts=opts.TitleOpts(title=bar_title,pos_bottom='bottom',pos_left=str(pl)+'%'),
                    xaxis_opts=opts.AxisOpts(axislabel_opts={"rotate":50}),
                    yaxis_opts=opts.AxisOpts(max_=1))
bar.set_series_opts(label_opts=opts.LabelOpts(is_show=False))

page = Page(layout=Page.SimplePageLayout)
page.add(daily_increase_summary, daily_out_control_increase_summary, all_daily_increase, Out_daily_increase,Change_daily_increase)
page.add(bar,cumulative1,pie, daily_increase_summary_only_asymptomatic,daily_out_control_increase_summary_only_asymptomatic,daily_increase_summary_only_positive,daily_out_control_increase_summary_only_positive)
page.render("index.html")
# Out:
# {'ConfirmedCases': {'In_control': {'浦东新区': 464, '黄浦区': 257, '徐汇区': 107, '长宁区': 36, '静安区': 182, '普陀区': 77, '虹口区': 122, '杨浦区': 26, '闵行区': 270, '宝山区': 35, '嘉定区': 80, '松江区': 57, '青浦区': 67, '崇明区': 20}, 'Out_control': {'浦东新区': 61, '黄浦区': 15, '徐汇区': 34, '长宁区': 4, '静安区': 13, '普陀区': 7, '虹口区': 12, '杨浦区': 2, '闵行区': 8, '宝山区': 4, '青浦区': 1}, 'FromAsymptomatic': {'浦东新区': 195, '黄浦区': 96, '徐汇区': 3, '长宁区': 13, '静安区': 10, '普陀区': 16, '虹口区': 14, '杨浦区': 36, '闵行区': 111, '宝山区': 2, '嘉定区': 24, '金山区': 1, '松江区': 1, '青浦区': 4, '奉贤区': 2, '崇明区': 5}}, 'Asymptomatic': {'In_control': {'浦东新区': 4841, '黄浦区': 2693, '徐汇区': 1403, '长宁区': 563, '静安区': 1502, '普陀区': 423, '虹口区': 601, '杨浦区': 701, '闵行区': 1212, '宝山区': 916, '嘉定区': 629, '金山区': 8, '松江区': 265, '青浦区': 310, '奉贤区': 56, '崇明区': 55}, 'Out_control': {'浦东新区': 85, '黄浦区': 23, '徐汇区': 61, '长宁区': 2, '静安区': 26, '普陀区': 5, '虹口区': 4, '杨浦区': 1, '闵行区': 1, '嘉定区': 10, '松江区': 2, '青浦区': 7, '奉贤区': 2}}, 'all_confirmed_cases': '30107', 'all_cured_cases': '7568', 'all_in_treatment': '22522', 'all_critical_cases': '52', 'all_in_observation': '1', 'all_deaths': '17'}
# 'C:\\Users\\msi\\Covid19\\index.html'

# %%
print(all_data['2022-04-18'])
# Out:
# {'ConfirmedCases': {'In_control': {'浦东新区': 633, '黄浦区': 322, '徐汇区': 35, '长宁区': 69, '静安区': 179, '普陀区': 13, '虹口区': 120, '杨浦区': 57, '闵行区': 141, '宝山区': 94, '嘉定区': 62, '金山区': 3, '松江区': 123, '青浦区': 42, '奉贤区': 1}, 'Out_control': {'浦东新区': 54, '黄浦区': 35, '徐汇区': 16, '长宁区': 15, '静安区': 21, '普陀区': 7, '虹口区': 30, '杨浦区': 1, '闵行区': 6, '宝山区': 9, '嘉定区': 6, '松江区': 1, '青浦区': 12, '崇明区': 3}, 'FromAsymptomatic': {'浦东新区': 388, '黄浦区': 5, '徐汇区': 17, '长宁区': 109, '静安区': 3, '普陀区': 1, '虹口区': 83, '杨浦区': 6, '闵行区': 165, '宝山区': 100, '嘉定区': 4, '松江区': 67, '青浦区': 23, '奉贤区': 1, '崇明区': 2}}, 'Asymptomatic': {'In_control': {'浦东新区': 7582, '黄浦区': 2878, '徐汇区': 483, '长宁区': 480, '静安区': 803, '普陀区': 349, '虹口区': 853, '杨浦区': 415, '闵行区': 1050, '宝山区': 823, '嘉定区': 513, '金山区': 4, '松江区': 570, '青浦区': 165, '奉贤区': 12, '崇明区': 18}, 'Out_control': {'浦东新区': 174, '黄浦区': 83, '徐汇区': 21, '长宁区': 7, '静安区': 4, '普陀区': 1, '虹口区': 6, '杨浦区': 2, '闵行区': 10, '宝山区': 4, '嘉定区': 3, '松江区': 1, '青浦区': 15, '崇明区': 3}}, 'all_confirmed_cases': '27613', 'all_cured_cases': '5886', 'all_in_treatment': '21717', 'all_critical_cases': '21', 'all_in_observation': '0', 'all_deaths': '10'}
